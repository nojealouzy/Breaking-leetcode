# %%
def inverted_right_angled_traingle(n):
    star = n
    for i in range(1,n+1):
        print('*'*star)
        star -=1

# %%
inverted_right_angled_traingle(6)
# Out:
# ******
# *****
# ****
# ***
# **
# *
