# %%
'''
n = 5
output:
*
**
***
****
*****
'''
# Out:
# '\nn = 5\noutput:\n*\n**\n***\n****\n*****\n'

# %%
def generate_right_angled_traingle(n):
    for i in range(1,n+1):
        line = '*'*i
        print(repr(line))

# %%
generate_right_angled_traingle(6)
# Out:
# '*'
# '**'
# '***'
# '****'
# '*****'
# '******'
