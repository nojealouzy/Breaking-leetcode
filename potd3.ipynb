# %%
'''
produce square by m rows by n columns

m = 5
n = 6


then

******
******
******
******
******'''
# Out:
# '\nproduce square by m rows by n columns\n\nm = 5\nn = 6\n\n******'

# %%
def mbynsquare(m,n):
    for i in range(m):
        print("*"*n,end=" ")
        print()


mbynsquare(10,10)
# Out:
# **********
# **********
# **********
# **********
# **********
# **********
# **********
# **********
# **********
# **********
